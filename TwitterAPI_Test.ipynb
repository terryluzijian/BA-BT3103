# %%
import pickle
import tweepy

from BasicAPI import BasicAPI


def lambda_handler(event, context):
    twitter = TwitterAPI(event['lat'], event['lon'])
    return twitter.get_latest_twitter()


class TwitterAPI(BasicAPI):

    type_name = 'twitter'
    twitter_classifier = pickle.load(open('data/CLASSIFIER.obj', 'rb'))

    def __init__(self, user_lat, user_lon, search_distance=BasicAPI.proximity_threshold):
        super(TwitterAPI, self).__init__(user_lat, user_lon, search_distance)
        self.latest_twitter = []

    def get_latest_twitter(self):
        ACCESS_TOKEN = BasicAPI.api_key['Twitter']['ACCESS_TOKEN']
        ACCESS_SECRET = BasicAPI.api_key['Twitter']['ACCESS_SECRET']
        CONSUMER_KEY = BasicAPI.api_key['Twitter']['CONSUMER_KEY']
        CONSUMER_SECRET = BasicAPI.api_key['Twitter']['CONSUMER_SECRET']
        auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
        auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
        api = tweepy.API(auth)
        tweet = []
        for i in range(1):  # Only get nearest 200 * 20 per page
            rst = api.user_timeline('307781209', tweet_mode='extended', page=i)
            tweet += rst
        result = []
        for t in tweet:
            dct = {}
            dct['text'] = t.full_text
            dct['time'] = t.created_at
            result.append(dct)
        self.latest_twitter = result
        self.get_twitter_tag()
        return {'tweets': {'search_distance': self.search_distance,
                           'results': self.latest_twitter
                           }
                }

    def get_twitter_tag(self):
        for t in self.latest_twitter:
            t['tag'] = 'neg'
            if '[' in t['text']:
                t['tag'] = 'pos'
        for t in self.latest_twitter:
            if '[' not in t['text']:
                t['tag'] = TwitterAPI.twitter_classifier.classify(t['text'])

# %%
a = TwitterAPI(1.29464, 103.783)

# %%
a.get_latest_twitter()
# Out:
# {'tweets': {'results': [{'tag': 'pos',
#     'text': '[EWL]: Train svcs btwn #JooKoon &amp; #TuasLink will continue to be suspended till Sun, 19 Nov. Free regular &amp; bridging bus svcs will be avail btwn #JooKoon &amp; #TuasLink all day. Plan your journey &amp; cater for additional train travel time. Alternative transport: https://t.co/4Qu9aPQESU',
#     'time': datetime.datetime(2017, 11, 17, 10, 21, 6)},
#    {'tag': 'pos',
#     'text': '[EWL]: Train svcs btwn #JooKoon &amp; #TuasLink will continue to be suspended tmr. Free regular &amp; bridging bus svcs will be avail btwn #JooKoon &amp; #TuasLink all day tmr. Plan your journey early &amp; cater for additional train travel time on EWL. Other transport: https://t.co/LmN15nP6k6.',
#     'time': datetime.datetime(2017, 11, 16, 12, 42, 45)},
#    {'tag': 'pos',
#     'text': '[NSL]: Train service on the NSL is running normally.',
#     'time': datetime.datetime(2017, 11, 15, 20, 44, 1)},
#    {'tag': 'pos',
#     'text': '[EWL]:Train svc btwn #JooKoon &amp; #TuasLink is suspended. Free regular &amp; bridging bus svcs are available btwn #JooKoon &amp; #TuasLink all day.',
#     'time': datetime.datetime(2017, 11, 15, 20, 43, 20)},
#    {'tag': 'pos',
#     'text': '[NSL] update: Train service on North South Line has running normally now.',
#     'time': datetime.datetime(2017, 11, 15, 14, 18, 3)},
#    {'tag': 'pos',
#     'text': '[NSL] UPDATE: Due to fewer trains serving the NSL tmr, pls add 40mins train travel time. Free bridging bus svcs from #Yishun to #MarinaSouthPier (one way) and free regular bus svcs between #Yishun and #MarinaSouthPier (both directions) are avail from the start of train service.',
#     'time': datetime.datetime(2017, 11, 15, 12, 33, 26)},
#    {'tag': 'pos',
#     'text': '[EWL]UPDATE:Train svcs btwn #JooKoon &amp; #TuasLink will be suspended tmr. Free regular bus &amp; bridging bus svcs will be avail btwn #JooKoon &amp; #TuasLink all day tmr. Plan your journey early &amp; cater for additional train travel time on EWL.Alternative transport:https://t.co/LmN15nP6k6.',
#     'time': datetime.datetime(2017, 11, 15, 12, 29, 27)},
#    {'tag': 'pos',
#     'text': '[NSL] UPDATE: Free regular bus and bridging bus services between #Bishan and #Yishun have ended.',
#     'time': datetime.datetime(2017, 11, 15, 12, 19, 43)},
#    {'tag': 'pos',
#     'text': '[NSL] UPDATE: Pls add 40 mins train travel time when commuting on the NSL. Free bridging bus services from #Bishan to #Yishun (one way) and free regular bus services btwn #Bishan and #Yishun (both directions) are still avail. Commuters are advised to take alternative train lines.',
#     'time': datetime.datetime(2017, 11, 15, 10, 29, 29)},
#    {'tag': 'pos',
#     'text': '[NSL] UPDATE: Pls add 25 mins train travel time when commuting on the NSL. Free bridging bus services from #Bishan to #Yishun (one way) and free regular bus services btwn #Bishan and #Yishun (both directions) are available. Pls seek alternative transport: https://t.co/LmN15nP6k6.',
#     'time': datetime.datetime(2017, 11, 15, 9, 45, 2)},
#    {'tag': 'pos',
#     'text': '[EWL] UPDATE: Free regular bus and bridging bus services between #BoonLay and #TuasLink have ended.',
#     'time': datetime.datetime(2017, 11, 15, 9, 34, 54)},
#    {'tag': 'pos',
#     'text': '[EWL] UPDATE: Train services between #BoonLay and #TuasLink have resumed but are running slower. Commuters travelling between #JurongEast and #TuasLink are advised to cater additional 10 minutes travelling time.',
#     'time': datetime.datetime(2017, 11, 15, 9, 15, 45)},
#    {'tag': 'pos',
#     'text': '[NSL]: Due to fewer trains serving the NSL this evening, please cater additional 15 minutes train travel time. Free bridging bus services from #Bishan to #Yishun (one way) and free regular bus services between #Bishan and #Yishun (both directions) are available.',
#     'time': datetime.datetime(2017, 11, 15, 9, 5, 7)},
#    {'tag': 'pos',
#     'text': '[EWL] UPDATE: No train service between #BoonLay and #TuasLink. Free regular bus and bridging bus services are available between #BoonLay and #TuasLink. Please seek alternative transport: https://t.co/4Qu9aPz41m. We are sorry that your journey has been affected.',
#     'time': datetime.datetime(2017, 11, 15, 5, 58, 19)},
#    {'tag': 'pos',
#     'text': '[EWL] UPDATE: Please add 10 mins train travel time between #BoonLay and #TuasLink. Free regular bus services are still available between #JurongEast and #TuasLink.',
#     'time': datetime.datetime(2017, 11, 15, 2, 31, 56)},
#    {'tag': 'pos',
#     'text': '[EWL] UPDATE: Please add 15 mins train travel time between #JurongEast and #TuasLink. Free regular bus services are still available between #JurongEast and #TuasLink.',
#     'time': datetime.datetime(2017, 11, 15, 1, 58, 19)},
#    {'tag': 'pos',
#     'text': '[CCL]CLEARED: Free regular bus services have ceased.',
#     'time': datetime.datetime(2017, 11, 15, 1, 46, 28)},
#    {'tag': 'pos',
#     'text': '[EWL] UPDATE: Due to a train fault, please add 30mins train travel time between #Queenstown and #TuasLink. Free regular bus services are available between #JurongEast and #TuasLink.',
#     'time': datetime.datetime(2017, 11, 15, 1, 26, 51)},
#    {'tag': 'pos',
#     'text': '[EWL] UPDATE: Pls add 30mins train travel time btwn #JurongEast and #TuasLink. We are working to recover svc.',
#     'time': datetime.datetime(2017, 11, 15, 1, 0, 41)},
#    {'tag': 'pos',
#     'text': '[EWL] UPDATE: Pls add 30mins train travel time btwn #JurongEast and #TuasLink due to a train fault at #JooKoon. Train svc is available.',
#     'time': datetime.datetime(2017, 11, 15, 0, 37, 47)}],
#   'search_distance': 0.3}}

# %%
BasicAPI.api_key['Twitter']
# Out:
# [{'ACCESS_TOKEN': '2675454162-YfUGh6ff2y1qmDTXPrjlJCT2QckIQ7O8X9WeBLe'},
#  {'ACCESS_SECRET': '2Aq398sbkCXKXkLZWBNoWSGkIXmsZP0yQquEXxh6nm2HL'},
#  {'CONSUMER_KEY': 'HAHth0DpaQpdHk15i9Xx6l3f8'},
#  {'CONSUMER_SECRET': 'xXivCvBS6DsvNg38aAIWQRye2XCV7dLOzWJKXGR07wXotHKP8U'}]

# %%
dct = {"Public Taxi/Bus": "8LOiGaQeTXO97oC7KkSYHA==",
       "Ofo": "3e9133f0-a27b-11e7-882a-5937e108b29a",
       "Twitter":{"ACCESS_TOKEN": "2675454162-YfUGh6ff2y1qmDTXPrjlJCT2QckIQ7O8X9WeBLe",
                  "ACCESS_SECRET" : "2Aq398sbkCXKXkLZWBNoWSGkIXmsZP0yQquEXxh6nm2HL",
                  "CONSUMER_KEY" : "HAHth0DpaQpdHk15i9Xx6l3f8",
                  "CONSUMER_SECRET" : "xXivCvBS6DsvNg38aAIWQRye2XCV7dLOzWJKXGR07wXotHKP8U"}
}

# %%
import json
with open('API_KEY.json', 'w') as outfile:
    json.dump(dct, outfile)

# %%
api_key = {key: value for sub_dict in json.load(open('data/API_KEY.json', 'r')) for key, value in sub_dict.items()}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-228ac346d149> in <module>()
# ----> 1 api_key = {key: value for sub_dict in json.load(open('data/API_KEY.json', 'r')) for key, value in sub_dict.items()}
#
# <ipython-input-53-228ac346d149> in <dictcomp>(.0)
# ----> 1 api_key = {key: value for sub_dict in json.load(open('data/API_KEY.json', 'r')) for key, value in sub_dict.items()}
#
# AttributeError: 'str' object has no attribute 'items'

# %%
a = json.load(open('data/API_KEY.json', 'r'))

# %%
a['Twitter']
# Out:
# {'ACCESS_SECRET': '2Aq398sbkCXKXkLZWBNoWSGkIXmsZP0yQquEXxh6nm2HL',
#  'ACCESS_TOKEN': '2675454162-YfUGh6ff2y1qmDTXPrjlJCT2QckIQ7O8X9WeBLe',
#  'CONSUMER_KEY': 'HAHth0DpaQpdHk15i9Xx6l3f8',
#  'CONSUMER_SECRET': 'xXivCvBS6DsvNg38aAIWQRye2XCV7dLOzWJKXGR07wXotHKP8U'}

# %%
# Import the necessary package to process data in JSON format
import json

# Import the necessary methods from "twitter" library
from twitter import Twitter, OAuth, TwitterHTTPError, TwitterStream

# Variables that contains the user credentials to access Twitter API 
ACCESS_TOKEN = '2675454162-YfUGh6ff2y1qmDTXPrjlJCT2QckIQ7O8X9WeBLe'
ACCESS_SECRET = '2Aq398sbkCXKXkLZWBNoWSGkIXmsZP0yQquEXxh6nm2HL'
CONSUMER_KEY = 'HAHth0DpaQpdHk15i9Xx6l3f8'
CONSUMER_SECRET = 'xXivCvBS6DsvNg38aAIWQRye2XCV7dLOzWJKXGR07wXotHKP8U'

oauth = OAuth(ACCESS_TOKEN, ACCESS_SECRET, CONSUMER_KEY, CONSUMER_SECRET)

# Initiate the connection to Twitter Streaming API
twitter_stream = TwitterStream(auth=oauth)

# Get a sample of the public data following through Twitter
iterator = twitter_stream.statuses.sample()

# Print each tweet in the stream to the screen 
# Here we set it to stop after getting 1000 tweets. 
# You don't have to set it to stop, but can continue running 
# the Twitter API to collect data for days or even longer. 
tweet_count = 10
for tweet in iterator:
    tweet_count -= 1
    # Twitter Python Tool wraps the data returned by Twitter 
    # as a TwitterDictResponse object.
    # We convert it back to the JSON format to print/score
    print (json.dumps(tweet))
    
    # The command below will do pretty printing for JSON data, try it out
    # print json.dumps(tweet, indent=4)
       
    if tweet_count <= 0:
        break
# Out:
# {"in_reply_to_status_id": null, "truncated": false, "geo": null, "coordinates": null, "place": null, "created_at": "Sat Nov 18 11:10:33 +0000 2017", "user": {"time_zone": "Bangkok", "profile_use_background_image": false, "translator_type": "none", "default_profile_image": false, "url": null, "created_at": "Sat May 06 15:39:29 +0000 2017", "profile_image_url_https": "https://pbs.twimg.com/profile_images/926358798054309888/Qvdham3m_normal.jpg", "profile_image_url": "http://pbs.twimg.com/profile_images/926358798054309888/Qvdham3m_normal.jpg", "screen_name": "nnparich", "notifications": null, "contributors_enabled": false, "lang": "th", "id": 860881713110458368, "friends_count": 360, "description": "ASTRO\u2721 | Wanna be your star! | WANNA ONE | \u0e40\u0e21\u0e19\u0e0b\u0e32\u0e19\u0e2e\u0e32\u0e40\u0e2b\u0e19\u0e37\u0e2d\u0e40\u0e21\u0e19\u0e04\u0e37\u0e2d\u0e1e\u0e35\u0e48\u0e21\u0e22\u0e2d\u0e07\u0e08\u0e38\u0e19\u0e40\u0e2b\u0e19\u0e37\u0e2d\u0e1e\u0e35\u0e48\u0e21\u0e22\u0e2d\u0e07\u0e08\u0e38\u0e19\u0e22\u0e31\u0e07\u0e21\u0e35\u0e04\u0e38\u0e13\u0e41\u0e14\u0e19\u0e40\u0e2b\u0e19\u0e37\u0e2d\u0e04\u0e38\u0e13\u0e41\u0e14\u0e19\u0e22\u0e31\u0e07\u0e21\u0e35\u0e1e\u0e34\u0e0b\u0e2d\u0e07\u0e2d\u0e38\u0e19 \ud83d\udc9c #\uc544\uc2a4\ud2b8\ub85c #SANHA #\u0e04\u0e31\u0e07\u0e41\u0e14\u0e40\u0e19\u0e35\u0e22\u0e25 #\u0e2e\u0e32\u0e0b\u0e2d\u0e07\u0e2d\u0e38\u0e19", "name": "\u0e17\u0e32\u0e2a\u0e23\u0e31\u0e01\u0e22\u0e31\u0e22\u0e15\u0e32\u0e19\u0e32", "following": null, "profile_background_tile": false, "verified": false, "profile_banner_url": "https://pbs.twimg.com/profile_banners/860881713110458368/1509687475", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "statuses_count": 23938, "profile_text_color": "000000", "utc_offset": 25200, "id_str": "860881713110458368", "geo_enabled": false, "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "protected": false, "follow_request_sent": null, "profile_background_color": "000000", "listed_count": 0, "followers_count": 80, "profile_sidebar_border_color": "000000", "favourites_count": 1047, "profile_sidebar_fill_color": "000000", "profile_link_color": "981CEB", "default_profile": false, "is_translator": false, "location": "Bangkok, Thailand"}, "in_reply_to_screen_name": null, "timestamp_ms": "1511003433665", "entities": {"symbols": [], "urls": [], "hashtags": [], "user_mentions": []}, "lang": "th", "id": 931842056292507648, "filter_level": "low", "in_reply_to_status_id_str": null, "is_quote_status": false, "retweeted": false, "contributors": null, "reply_count": 0, "text": "\u0e01\u0e39\u0e2d\u0e22\u0e32\u0e01\u0e1f\u0e31\u0e07\u0e2d\u0e2d\u0e01\u0e27\u0e48\u0e32\u0e40\u0e04\u0e49\u0e32\u0e04\u0e38\u0e22\u0e44\u0e23\u0e01\u0e31\u0e19", "in_reply_to_user_id": null, "id_str": "931842056292507648", "favorited": false, "retweet_count": 0, "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>", "favorite_count": 0, "in_reply_to_user_id_str": null, "quote_count": 0}
# {"in_reply_to_status_id": null, "truncated": true, "geo": null, "coordinates": null, "place": null, "created_at": "Sat Nov 18 11:10:33 +0000 2017", "user": {"time_zone": null, "profile_use_background_image": true, "translator_type": "none", "default_profile_image": false, "url": null, "created_at": "Fri Apr 01 04:27:24 +0000 2016", "profile_image_url_https": "https://pbs.twimg.com/profile_images/926097485478506496/2wt3mPCk_normal.jpg", "profile_image_url": "http://pbs.twimg.com/profile_images/926097485478506496/2wt3mPCk_normal.jpg", "screen_name": "969696369kutan", "notifications": null, "contributors_enabled": false, "lang": "ja", "id": 715757430727184385, "friends_count": 1046, "description": "\u3010\u3082\u3068\u307e\u308b\u30e1\u30a4\u30c4\u3011\u300e\u3054\u5f53\u5730\u30bf\u30ec\u30f3\u30c8\u7814\u4fee\u751f\u300f\u306e\u304f\u308b\u307f\u3067\u3059.*\uff65\uff9f\u3000  \u2661\u304e\u3075\u30c1\u30e3\u30f3\u300a \u30ec\u30ae\u30e5\u30e9\u30fc\u300b\u2661\u3082\u3068\u307e\u308b\u304f\u3093\u2661\u3054\u5f53\u5730\u30ad\u30e3\u30e9\u3055\u3093love \u2661\u57fa\u672c\u30d5\u30a9\u30ed\u30d0\u3057\u307e\u3059\ud83d\udc93\ud83d\udc93", "name": "\u304f\u308b\u307f\u3010\u3082\u3068\u307e\u308b\u30e1\u30a4\u30c4\u3011", "following": null, "profile_background_tile": false, "verified": false, "profile_banner_url": "https://pbs.twimg.com/profile_banners/715757430727184385/1479690019", "profile_background_image_url_https": "", "statuses_count": 3049, "profile_text_color": "333333", "utc_offset": null, "id_str": "715757430727184385", "geo_enabled": false, "profile_background_image_url": "", "protected": false, "follow_request_sent": null, "profile_background_color": "F5F8FA", "listed_count": 9, "followers_count": 1052, "profile_sidebar_border_color": "C0DEED", "favourites_count": 4826, "profile_sidebar_fill_color": "DDEEF6", "profile_link_color": "1DA1F2", "default_profile": true, "is_translator": false, "location": "\u5c90\u961c\u770c"}, "extended_tweet": {"entities": {"symbols": [], "urls": [], "hashtags": [], "user_mentions": [], "media": [{"type": "photo", "media_url": "http://pbs.twimg.com/media/DO6RZR9VwAAfkNv.jpg", "id": 931842036415709184, "media_url_https": "https://pbs.twimg.com/media/DO6RZR9VwAAfkNv.jpg", "indices": [146, 169], "id_str": "931842036415709184", "sizes": {"thumb": {"resize": "crop", "w": 150, "h": 150}, "small": {"resize": "fit", "w": 383, "h": 680}, "large": {"resize": "fit", "w": 720, "h": 1280}, "medium": {"resize": "fit", "w": 675, "h": 1200}}, "url": "https://t.co/ZqA1lPOohc", "display_url": "pic.twitter.com/ZqA1lPOohc", "expanded_url": "https://twitter.com/969696369kutan/status/931842056288321536/photo/1"}]}, "extended_entities": {"media": [{"type": "photo", "media_url": "http://pbs.twimg.com/media/DO6RZR9VwAAfkNv.jpg", "id": 931842036415709184, "media_url_https": "https://pbs.twimg.com/media/DO6RZR9VwAAfkNv.jpg", "indices": [146, 169], "id_str": "931842036415709184", "sizes": {"thumb": {"resize": "crop", "w": 150, "h": 150}, "small": {"resize": "fit", "w": 383, "h": 680}, "large": {"resize": "fit", "w": 720, "h": 1280}, "medium": {"resize": "fit", "w": 675, "h": 1200}}, "url": "https://t.co/ZqA1lPOohc", "display_url": "pic.twitter.com/ZqA1lPOohc", "expanded_url": "https://twitter.com/969696369kutan/status/931842056288321536/photo/1"}]}, "display_text_range": [0, 145], "full_text": "\u30b7\u30f3\u30c7\u30ec\u30e9\u30c9\u30ea\u30fc\u30e0\u30ba\u30b3\u30ec\u30af\u30b7\u30e7\u30f3\u306eshowroom\u914d\u4fe1\u306b\u7686\u69d8\u6765\u3066\u3044\u305f\u3060\u304d\u672c\u5f53\u306b\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3057\u305f\u3002\n\u6ce3\u3044\u3066\u3057\u307e\u3063\u305f\u306e\u306f\u7686\u69d8\u306e\u5fdc\u63f4\u304c\u672c\u5f53\u306b\u5b09\u3057\u304b\u3063\u305f\u304b\u3089\u3067\u3059\u3002\u5e78\u305b\u3067\u697d\u3057\u304f\u3066\u4ed5\u65b9\u306a\u3044\u5b9d\u7269\u306e\u6642\u9593\u3092\u3042\u308a\u304c\u3068\u3046\u3054\u3056\u3044\u307e\u3057\u305f\u3002\u9806\u4f4d\u306f4\ ...
# {"delete": {"timestamp_ms": "1511003434331", "status": {"id_str": "778273248274448384", "user_id_str": "2723478078", "id": 778273248274448384, "user_id": 2723478078}}}
# {"delete": {"timestamp_ms": "1511003434411", "status": {"id_str": "931823399998930944", "user_id_str": "1709538842", "id": 931823399998930944, "user_id": 1709538842}}}
# {"in_reply_to_status_id": null, "truncated": false, "geo": null, "coordinates": null, "place": null, "created_at": "Sat Nov 18 11:10:33 +0000 2017", "user": {"time_zone": null, "profile_use_background_image": true, "translator_type": "none", "default_profile_image": false, "url": null, "created_at": "Wed Nov 11 23:22:57 +0000 2015", "profile_image_url_https": "https://pbs.twimg.com/profile_images/925201175888109570/nx4aDRE-_normal.jpg", "profile_image_url": "http://pbs.twimg.com/profile_images/925201175888109570/nx4aDRE-_normal.jpg", "screen_name": "camera_ape50", "notifications": null, "contributors_enabled": false, "lang": "ja", "id": 4206302294, "friends_count": 523, "description": "\u81ea\u7531\u306b\u5199\u771f\u64ae\u3063\u3066\u308b\u5927\u5b66\u751f\ud83d\udd30/EOS kiss x3\u2192EOS \n7D#\u5199\u771f\u597d\u304d\u306a\u4eba\u3068\u7e4b\u304c\u308a\u305f\u3044#\u30ab\u30e1\u30e9\u7537\u5b50", "name": "\u30a6\u30e1\uff08\u5199\u771f\uff09", "following": null, "profile_background_tile": false, "verified": false, "profile_banner_url": "https://pbs.twimg.com/profile_banners/4206302294/1505998400", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "statuses_count": 1801, "profile_text_color": "333333", "utc_offset": null, "id_str": "4206302294", "geo_enabled": false, "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "protected": false, "follow_request_sent": null, "profile_background_color": "C0DEED", "listed_count": 1, "followers_count": 500, "profile_sidebar_border_color": "C0DEED", "favourites_count": 3553, "profile_sidebar_fill_color": "DDEEF6", "profile_link_color": "1DA1F2", "default_profile": true, "is_translator": false, "location": "\u65e5\u672c \u5343\u8449"}, "display_text_range": [0, 11], "timestamp_ms": "1511003433659", "entities": {"symbols": [], "urls": [], "hashtags": [], "user_mentions": [], "media": [{"type": "photo", "media_url": "http://pbs.twimg.com/media/DO6RYxxUMAAUjdi.jpg", "id": 931842027775340544, "media_url_https": "https://pbs.twimg.com/media/DO6RYxxUMAAUjdi.jpg", "indices": [12, 35], "id_str": "931842027775340544", "sizes": {"thumb": {"resize": "crop", "w": 150, "h": 150}, "small": {"resize": "fit", "w": 680, "h": 383}, "large": {"resize": "fit", "w": 2048, "h": 1152}, "medium": {"resize": "fit", "w": 1200, "h": 675}}, "url": "https://t.co/hifWWwZjXh", "display_url": "pic.twitter.com/hifWWwZjXh", "expanded_url": "https://twitter.com/camera_ape50/status/931842056267239424/photo/1"}]}, "lang": "ja", "id": 931842056267239424, "filter_level": "low", "in_reply_to_status_id_str": null, "is_quote_status": false, "retweeted": false, "contributors": null, "reply_count": 0, "text": "\u30d5\u30eb\u30b5\u30a4\u30ba\u3044\u3044\u306a\u3002\u3002\u3002 https://t.co/hifWWwZjXh", "in_reply_to_user_id": null, "extended_entities": {"media": [{"type": "photo", "media_url": "http://pbs.twimg.com/media/DO6RYxxUMAAUjdi.jpg", "id": 931842027775340544, "media_url_https": "https://pbs.twimg.com/media/DO6RYxxUMAAUjdi.jpg", "indices": [12, 35], "id_str": "931842027775340544", "sizes": {"thumb": {"resize": "crop", "w": 150, "h": 150}, "small": {"resize": "fit", "w": 680, "h": 383}, "large": {"resize": "fit", "w": 2048, "h": 1152}, "medium": {"resize": "fit", "w": 1200, "h": 675}}, "url": "https://t.co/hifWWwZjXh", "display_url": "pic.twitter.com/hifWWwZjXh", "expanded_url": "https://twitter.com/camera_ape50/status/931842056267239424/photo/1"}, {"type": "photo", "media_url": "http://pbs.twimg.com/media/DO6RZtFU8AAhFiZ.jpg", "id": 931842043696967680, "media_url_https": "https://pbs.twimg.com/media/DO6RZtFU8AAhFiZ.jpg", "indices": [12, 35], "id_str": "931842043696967680", "sizes": {"thumb": {"resize": "crop", "w": 150, "h": 150}, "small": {"resize": "fit", "w": 680, "h": 383}, "large": {"resize": "fit", "w": 2048, "h": 1152}, "medium": {"resize": "fit", "w": 1200, "h": 675}}, "url": "https://t.co/hifWWwZjXh", "display_url": "pic.twitter.com/hifWWwZjXh",  ...
# {"delete": {"timestamp_ms": "1511003434479", "status": {"id_str": "778164456404705280", "user_id_str": "2723478078", "id": 778164456404705280, "user_id": 2723478078}}}
# {"delete": {"timestamp_ms": "1511003434649", "status": {"id_str": "931517157094989825", "user_id_str": "903128863315656705", "id": 931517157094989825, "user_id": 903128863315656705}}}
# {"in_reply_to_status_id": null, "truncated": false, "geo": null, "coordinates": null, "place": null, "created_at": "Sat Nov 18 11:10:34 +0000 2017", "user": {"time_zone": null, "profile_use_background_image": false, "translator_type": "none", "default_profile_image": false, "url": "http://minamibofx.blog.fc2.com/", "created_at": "Sun Jan 22 12:59:16 +0000 2017", "profile_image_url_https": "https://pbs.twimg.com/profile_images/823154042524180480/UBa36lNq_normal.jpg", "profile_image_url": "http://pbs.twimg.com/profile_images/823154042524180480/UBa36lNq_normal.jpg", "screen_name": "BofxMinami", "notifications": null, "contributors_enabled": false, "lang": "ja", "id": 823153053691875330, "friends_count": 1646, "description": "\u30a4\u30c1\u4e3b\u5a66Minami\u3067\u3059\u3002\u3000\u3000\u3000\u3000\u3000\u3000\u3000\u3000 \u30b3\u30a2\u30e9\u3068\u30d3\u30fc\u30eb\u304c\u597d\u304d\u306a\u3075\u305f\u308a\u306e\u5a18\u3092\u3082\u3064\u30de\u30de\u3067\u3059\u3002 \u30a2\u30e9\u30d5\u30a9\u30fc\u3067\u3059\u3002\u57fa\u672c\u3072\u304d\u3053\u3082\u308a\u3067\u3059\uff65\uff65\uff65\u3000\u9589\u6240\u6050\u6016\u75c7\u3067\u3059\uff65\uff65\uff65  \u5b50\u4f9b\u306e\u7fd2\u3044\u4e8b\u306b\u5e742\u56de\u306e\u6d77\u5916\u65c5\u884c \u30b7\u30fc\u30ba\u30f3\u3054\u3068\u306e\u6e29\u6cc9\u65c5\u884c\u3000 \u65e6\u90a3\u306e\u7a3c\u304e\u304c\u5c11\u3005\u5c11\u306a\u304f\u305f\u3063\u3066\u5341\u5206\u3084\u3063\u3066\u3044\u3051\u307e\u3059\u3088\uff01 \u3068\u3044\u3046\u3053\u3068\u3067\u30d0\u30a4\u30ca\u30ea\u30fc\u3084\u3063\u3066\u307e\u3059\uff01", "name": "Minami@\u30d0\u30a4\u30aa\u30d7\u4e3b\u5a66", "following": null, "profile_background_tile": false, "verified": false, "profile_banner_url": "https://pbs.twimg.com/profile_banners/823153053691875330/1485091164", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "statuses_count": 4287, "profile_text_color": "000000", "utc_offset": null, "id_str": "823153053691875330", "geo_enabled": false, "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "protected": false, "follow_request_sent": null, "profile_background_color": "000000", "listed_count": 1, "followers_count": 5324, "profile_sidebar_border_color": "000000", "favourites_count": 879, "profile_sidebar_fill_color": "000000", "profile_link_color": "981CEB", "default_profile": false, "is_translator": false, "location": "\u6771\u4eac"}, "in_reply_to_screen_name": null, "timestamp_ms": "1511003434658", "entities": {"symbols": [], "urls": [], "hashtags": [], "user_mentions": []}, "lang": "ja", "id": 931842060457406464, "filter_level": "low", "in_reply_to_status_id_str": null, "is_quote_status": false, "retweeted": false, "contributors": null, "reply_count": 0, "text": "\u30ef\u30ad\u306e\u8131\u6bdb\u3092\u884c\u3063\u305f\u5f8c\u306b\u6bba\u83cc\u4f5c\u7528\u306e\u3042\u308b\u30af\u30ea\u30fc\u30e0\u3092\u5857\u3063\u3066\u304a\u3051\u3070\u3001\u6bdb\u7a74\u304c\u708e\u75c7\u3092\u8d77\u3053\u3057\u3066\u3057\u307e\u3046\u3068\u3044\u3046\u5fc3\u914d\u3082\u306a\u3044\u3067\u3059\u3057\u885b\u751f\u7684\u306b\u4fdd\u3064\u3053\u3068\u304c\u3067\u304d\u307e\u3059", "in_reply_to_user_id": null, "id_str": "931842060457406464", "favorited": false, "retweet_count": 0, "source": "<a href=\"http://twittbot.net/\" rel=\"nofollow\">twittbot.net</a>", "favorite_count": 0, "in_reply_to_user_id_str": null, "quote_count": 0}
# {"in_reply_to_status_id": null, "truncated": false, "geo": null, "coordinates": null, "place": null, "created_at": "Sat Nov 18 11:10:34 +0000 2017", "user": {"time_zone": "Pacific Time (US & Canada)", "profile_use_background_image": false, "translator_type": "none", "default_profile_image": false, "url": null, "created_at": "Sat Nov 07 10:40:28 +0000 2015", "profile_image_url_https": "https://pbs.twimg.com/profile_images/891137816133943296/cNPi6yqT_normal.jpg", "profile_image_url": "http://pbs.twimg.com/profile_images/891137816133943296/cNPi6yqT_normal.jpg", "screen_name": "MSuphutcha", "notifications": null, "contributors_enabled": false, "lang": "en", "id": 4156135932, "friends_count": 170, "description": "\u0e42\u0e15\u0e41\u0e25\u0e49\u0e27\u0e04\u0e34\u0e14\u0e44\u0e14\u0e49\u0e41\u0e25\u0e49\u0e27 | \u0e01\u0e33\u0e40\u0e40\u0e1e\u0e07\u0e21\u0e31\u0e19\u0e2a\u0e39\u0e07\u0e2d\u0e22\u0e48\u0e32\u0e17\u0e33\u0e25\u0e32\u0e22\u0e40\u0e25\u0e22\n\ud83c\udf35\ud83c\udf43", "name": "M", "following": null, "profile_background_tile": false, "verified": false, "profile_banner_url": "https://pbs.twimg.com/profile_banners/4156135932/1469596252", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "statuses_count": 12940, "profile_text_color": "000000", "utc_offset": -28800, "id_str": "4156135932", "geo_enabled": true, "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "protected": false, "follow_request_sent": null, "profile_background_color": "000000", "listed_count": 3, "followers_count": 127, "profile_sidebar_border_color": "000000", "favourites_count": 1156, "profile_sidebar_fill_color": "000000", "profile_link_color": "ABB8C2", "default_profile": false, "is_translator": false, "location": null}, "in_reply_to_screen_name": null, "timestamp_ms": "1511003434661", "retweeted_status": {"in_reply_to_status_id": null, "truncated": false, "geo": null, "coordinates": null, "place": null, "created_at": "Sat Nov 18 07:29:37 +0000 2017", "user": {"time_zone": null, "profile_use_background_image": true, "translator_type": "none", "default_profile_image": false, "url": null, "created_at": "Thu Mar 23 19:36:53 +0000 2017", "profile_image_url_https": "https://pbs.twimg.com/profile_images/845130884827131908/mbn3r63D_normal.jpg", "profile_image_url": "http://pbs.twimg.com/profile_images/845130884827131908/mbn3r63D_normal.jpg", "screen_name": "bnrpvlp", "notifications": null, "contributors_enabled": false, "lang": "th", "id": 844996388345675776, "friends_count": 18, "description": null, "name": "\u0e44\u0e1a\u0e23\u0e4c\u0e17\u0e1b\u0e30\u0e27\u0e30", "following": null, "profile_background_tile": false, "verified": false, "profile_background_image_url_https": "", "statuses_count": 219, "profile_text_color": "333333", "utc_offset": null, "id_str": "844996388345675776", "geo_enabled": false, "profile_background_image_url": "", "protected": false, "follow_request_sent": null, "profile_background_color": "F5F8FA", "listed_count": 2, "followers_count": 30927, "profile_sidebar_border_color": "C0DEED", "favourites_count": 247, "profile_sidebar_fill_color": "DDEEF6", "profile_link_color": "1DA1F2", "default_profile": true, "is_translator": false, "location": null}, "retweet_count": 447, "entities": {"symbols": [], "urls": [], "hashtags": [], "user_mentions": []}, "lang": "th", "id": 931786457303343105, "filter_level": "low", "in_reply_to_status_id_str": null, "is_quote_status": false, "retweeted": false, "contributors": null, "reply_count": 25, "text": "\u0e23\u0e49\u0e2d\u0e19\u0e21\u0e32\u0e01\u0e27\u0e31\u0e19\u0e19\u0e35\u0e49 \u0e40\u0e2b\u0e25\u0e37\u0e2d\u0e1e\u0e23\u0e38\u0e49\u0e07\u0e19\u0e35\u0e49\u0e2d\u0e35\u0e01\u0e27\u0e31\u0e19\u0e08\u0e30\u0e44\u0e14\u0e49\u0e19\u0e2d\u0e19\u0e40\u0e15\u0e47\u0e21\u0e46\u0e41\u0e25\u0e49\u0e27\u0e27\u0e27\u0e27 \u0e2e\u0e36\u0e1a", "in_reply_to_user_id": null, "id_str": "931786457303343105", "favorited": false, "in_reply_to_screen_ ...
# {"in_reply_to_status_id": null, "truncated": false, "geo": null, "coordinates": null, "place": null, "created_at": "Sat Nov 18 11:10:34 +0000 2017", "user": {"time_zone": null, "profile_use_background_image": true, "translator_type": "none", "default_profile_image": false, "url": null, "created_at": "Mon Mar 10 13:16:22 +0000 2014", "profile_image_url_https": "https://pbs.twimg.com/profile_images/930382754843422727/Jf3EDoAe_normal.jpg", "profile_image_url": "http://pbs.twimg.com/profile_images/930382754843422727/Jf3EDoAe_normal.jpg", "screen_name": "ApplauesDay", "notifications": null, "contributors_enabled": false, "lang": "ja", "id": 2382138805, "friends_count": 65, "description": "\u679c\u5831\u306f\u5bdd\u3066\u5f85\u3066", "name": "misa7", "following": null, "profile_background_tile": false, "verified": false, "profile_banner_url": "https://pbs.twimg.com/profile_banners/2382138805/1405837170", "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png", "statuses_count": 606, "profile_text_color": "333333", "utc_offset": null, "id_str": "2382138805", "geo_enabled": false, "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png", "protected": false, "follow_request_sent": null, "profile_background_color": "C0DEED", "listed_count": 0, "followers_count": 7, "profile_sidebar_border_color": "C0DEED", "favourites_count": 140, "profile_sidebar_fill_color": "DDEEF6", "profile_link_color": "1DA1F2", "default_profile": true, "is_translator": false, "location": null}, "in_reply_to_screen_name": null, "timestamp_ms": "1511003434659", "retweeted_status": {"in_reply_to_status_id": null, "truncated": true, "geo": null, "coordinates": null, "place": null, "created_at": "Thu Nov 16 18:55:22 +0000 2017", "user": {"time_zone": null, "profile_use_background_image": true, "translator_type": "none", "default_profile_image": false, "url": null, "created_at": "Wed Jan 11 14:17:51 +0000 2017", "profile_image_url_https": "https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png", "profile_image_url": "http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png", "screen_name": "ajt92031260", "notifications": null, "contributors_enabled": false, "lang": "ja", "id": 819186565893099520, "friends_count": 0, "description": null, "name": "ajt", "following": null, "profile_background_tile": false, "verified": false, "profile_background_image_url_https": "", "statuses_count": 29, "profile_text_color": "333333", "utc_offset": null, "id_str": "819186565893099520", "geo_enabled": false, "profile_background_image_url": "", "protected": false, "follow_request_sent": null, "profile_background_color": "F5F8FA", "listed_count": 0, "followers_count": 1, "profile_sidebar_border_color": "C0DEED", "favourites_count": 1, "profile_sidebar_fill_color": "DDEEF6", "profile_link_color": "1DA1F2", "default_profile": true, "is_translator": false, "location": null}, "retweet_count": 3664, "entities": {"symbols": [], "urls": [{"indices": [117, 140], "url": "https://t.co/0J2fghBnGW", "display_url": "twitter.com/i/web/status/9\u2026", "expanded_url": "https://twitter.com/i/web/status/931234254645628928"}], "hashtags": [], "user_mentions": []}, "lang": "ja", "id": 931234254645628928, "filter_level": "low", "in_reply_to_status_id_str": null, "is_quote_status": false, "extended_tweet": {"entities": {"symbols": [], "urls": [], "hashtags": [], "user_mentions": []}, "display_text_range": [0, 144], "full_text": "\u5b50\u3069\u3082\u306a\u3057\u4e16\u5e2f\u306f\u5e74\u53ce800\u4e07\u5186\u8d85\u3067\u5897\u7a0e\u6848\n\n\u4e16\u5e2f\u5e74\u53ce\u3067\u3042\u308c\u3070\u3001\u6b86\u3069\u304c\u8a72\u5f53\u3059\u308b\u306f\u305a\u3002\n\u300e\u5b50\u4f9b\u306a\u3057\u300f\u3067\u306e\u7dda\u5f15\u304d\u306f\u3001\u671b\u3093\u3067\u3082\u5b50\u4f9b\u306b\u6075\u307e\u308c\u306a\u304b\u3063\u305f\u5973\u6027\u304b\u3089\u3059\u308b\u3068\u5dee\u5225\u7684\u3060\u3068\u611f\u3058\u307e\u3059\u300 ...

# %%
import requests
ACCESS_TOKEN = '2675454162-YfUGh6ff2y1qmDTXPrjlJCT2QckIQ7O8X9WeBLe'
ACCESS_SECRET = '2Aq398sbkCXKXkLZWBNoWSGkIXmsZP0yQquEXxh6nm2HL'
CONSUMER_KEY = 'HAHth0DpaQpdHk15i9Xx6l3f8'
CONSUMER_SECRET = 'xXivCvBS6DsvNg38aAIWQRye2XCV7dLOzWJKXGR07wXotHKP8U'

oauth = OAuth(ACCESS_TOKEN, ACCESS_SECRET, CONSUMER_KEY, CONSUMER_SECRET)
# auth = {'ACCESS_TOKEN' : '2675454162-YfUGh6ff2y1qmDTXPrjlJCT2QckIQ7O8X9WeBLe',
#         'ACCESS_SECRET' : '2Aq398sbkCXKXkLZWBNoWSGkIXmsZP0yQquEXxh6nm2HL',
#         'CONSUMER_KEY' : 'HAHth0DpaQpdHk15i9Xx6l3f8',
#         'CONSUMER_SECRET' : 'xXivCvBS6DsvNg38aAIWQRye2XCV7dLOzWJKXGR07wXotHKP8U'}
# GET statuses/user_timeline
# oauth = OAuth(ACCESS_TOKEN, ACCESS_SECRET, CONSUMER_KEY, CONSUMER_SECRET)

# %%
import requests
from requests_oauthlib import OAuth1
url = 'https://api.twitter.com/1.1/statuses/user_timeline.json'
auth = OAuth1(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_TOKEN, ACCESS_SECRET)
para = {'user_id': '307781209',
        'tweet_mode':'extended'}
result = requests.get(url, auth=auth, params=para)

# %%
result.json()[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Nov 17 10:21:06 +0000 2017',
#  'display_text_range': [0, 296],
#  'entities': {'hashtags': [{'indices': [23, 31], 'text': 'JooKoon'},
#    {'indices': [38, 47], 'text': 'TuasLink'},
#    {'indices': [152, 160], 'text': 'JooKoon'},
#    {'indices': [167, 176], 'text': 'TuasLink'}],
#   'symbols': [],
#   'urls': [{'display_url': 'bit.ly/2AMuuNK',
#     'expanded_url': 'http://bit.ly/2AMuuNK',
#     'indices': [273, 296],
#     'url': 'https://t.co/4Qu9aPQESU'}],
#   'user_mentions': []},
#  'favorite_count': 40,
#  'favorited': False,
#  'full_text': '[EWL]: Train svcs btwn #JooKoon &amp; #TuasLink will continue to be suspended till Sun, 19 Nov. Free regular &amp; bridging bus svcs will be avail btwn #JooKoon &amp; #TuasLink all day. Plan your journey &amp; cater for additional train travel time. Alternative transport: https://t.co/4Qu9aPQESU',
#  'geo': None,
#  'id': 931467221888524288,
#  'id_str': '931467221888524288',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 40,
#  'retweeted': False,
#  'source': '<a href="https://connect.smrt.wwprojects.com/" rel="nofollow">SMRTConnect Portal</a>',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Mon May 30 08:33:09 +0000 2011',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': 'Official Twitter channel for SMRT. Offers information and real-time train service updates. For feedback, drop a line to http://t.co/G2rbdPLYAu',
#   'entities': {'description': {'urls': [{'display_url': 'smrt.com.sg/Feedback.aspx',
#       'expanded_url': 'http://www.smrt.com.sg/Feedback.aspx',
#       'indices': [120, 142],
#       'url': 'http://t.co/G2rbdPLYAu'}]},
#    'url': {'urls': [{'display_url': 'smrt.com.sg',
#       'expanded_url': 'http://www.smrt.com.sg',
#       'indices': [0, 22],
#       'url': 'http://t.co/cZwdOdtPNk'}]}},
#   'favourites_count': 67,
#   'follow_request_sent': False,
#   'followers_count': 441730,
#   'following': True,
#   'friends_count': 5,
#   'geo_enabled': True,
#   'has_extended_profile': False,
#   'id': 307781209,
#   'id_str': '307781209',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 637,
#   'location': 'Singapore',
#   'name': 'SMRT Corporation',
#   'notifications': False,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/451568396979564544/S0rdDkd6.png',
#   'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/451568396979564544/S0rdDkd6.png',
#   'profile_background_tile': True,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/307781209/1510298026',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/769201640221966336/DSArTQ0v_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/769201640221966336/DSArTQ0v_normal.jpg',
#   'profile_link_color': '0084B4',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'SMRT_Singapore',
#   'statuses_count': 4016,
#   'time_zone': 'Singapore',
#   'translator_type': 'none',
#   'url': 'http://t.co/cZwdOdtPNk',
#   'utc_offset': 28800,
#   'verified': False}}

# %%
data = []
for r in result.json():
    dct = {}
    dct['created_at'] = r['created_at']
    dct['full_text'] = r['full_text']
    data.append(dct)

# %%
import pandas as pd
df = pd.DataFrame(data)

# %%
df
# Out:
#                         created_at  \
# 0   Fri Nov 17 10:21:06 +0000 2017
# 1   Thu Nov 16 12:42:45 +0000 2017
# 2   Wed Nov 15 20:44:01 +0000 2017
# 3   Wed Nov 15 20:43:20 +0000 2017
# 4   Wed Nov 15 14:18:03 +0000 2017
# 5   Wed Nov 15 12:33:26 +0000 2017
# 6   Wed Nov 15 12:29:27 +0000 2017
# 7   Wed Nov 15 12:19:43 +0000 2017
# 8   Wed Nov 15 10:29:29 +0000 2017
# 9   Wed Nov 15 09:45:02 +0000 2017
# 10  Wed Nov 15 09:34:54 +0000 2017
# 11  Wed Nov 15 09:15:45 +0000 2017
# 12  Wed Nov 15 09:05:07 +0000 2017
# 13  Wed Nov 15 05:58:19 +0000 2017
# 14  Wed Nov 15 02:31:56 +0000 2017
# 15  Wed Nov 15 01:58:19 +0000 2017
# 16  Wed Nov 15 01:46:28 +0000 2017
# 17  Wed Nov 15 01:26:51 +0000 2017
# 18  Wed Nov 15 01:00:41 +0000 2017
# 19  Wed Nov 15 00:37:47 +0000 2017
#
#                                             full_text
# 0   [EWL]: Train svcs btwn #JooKoon &amp; #TuasLin...
# 1   [EWL]: Train svcs btwn #JooKoon &amp; #TuasLin...
# 2   [NSL]: Train service on the NSL is running nor...
# 3   [EWL]:Train svc btwn #JooKoon &amp; #TuasLink ...
# 4   [NSL] update: Train service on North South Lin...
# 5   [NSL] UPDATE: Due to fewer trains serving the ...
# 6   [EWL]UPDATE:Train svcs btwn #JooKoon &amp; #Tu...
# 7   [NSL] UPDATE: Free regular bus and bridging bu...
# 8   [NSL] UPDATE: Pls add 40 mins train travel tim...
# 9   [NSL] UPDATE: Pls add 25 mins train travel tim...
# 10  [EWL] UPDATE: Free regular bus and bridging bu...
# 11  [EWL] UPDATE: Train services between #BoonLay ...
# 12  [NSL]: Due to fewer trains serving the NSL thi...
# 13  [EWL] UPDATE: No train service between #BoonLa...
# 14  [EWL] UPDATE: Please add 10 mins train travel ...
# 15  [EWL] UPDATE: Please add 15 mins train travel ...
# 16  [CCL]CLEARED: Free regular bus services have c...
# 17  [EWL] UPDATE: Due to a train fault, please add...
# 18  [EWL] UPDATE: Pls add 30mins train travel time...
# 19  [EWL] UPDATE: Pls add 30mins train travel time...

# %%
import requests
import pickle
from requests_oauthlib import OAuth1
from BasicAPI import BasicAPI


def lambda_handler(event, context):
    twitter = TwitterAPI(event['lat'], event['lon'])
    return twitter.get_latest_twitter()


class TwitterAPI(BasicAPI):

    type_name = 'twitter'
    # Dependency Issue in AWS
    twitter_classifier = pickle.load(open('data/CLASSIFIER.obj', 'rb'))

    def __init__(self, user_lat, user_lon, search_distance=BasicAPI.proximity_threshold):
        super(TwitterAPI, self).__init__(user_lat, user_lon, search_distance)
        self.latest_twitter = []

    def get_latest_twitter(self):  # Revise without tweepy
        ACCESS_TOKEN = BasicAPI.api_key['Twitter']['ACCESS_TOKEN']
        ACCESS_SECRET = BasicAPI.api_key['Twitter']['ACCESS_SECRET']
        CONSUMER_KEY = BasicAPI.api_key['Twitter']['CONSUMER_KEY']
        CONSUMER_SECRET = BasicAPI.api_key['Twitter']['CONSUMER_SECRET']
        url = 'https://api.twitter.com/1.1/statuses/user_timeline.json'
        auth = OAuth1(CONSUMER_KEY, CONSUMER_SECRET, ACCESS_TOKEN, ACCESS_SECRET)
        para = {'user_id': '307781209',
                'tweet_mode': 'extended'}
        result = requests.get(url, auth=auth, params=para)
        data = []
        for r in result.json():
            dct = {}
            dct['created_at'] = r['created_at']
            dct['full_text'] = r['full_text']
            data.append(dct)
        self.latest_twitter = data
        self.get_twitter_tag()
        return {'tweets': {'search_distance': self.search_distance,
                           'results': self.latest_twitter
                           }
                }

    def get_twitter_tag(self):
        for t in self.latest_twitter:
            t['tag'] = 'neg'
            if '[' in t['full_text']:
                t['tag'] = 'pos'
        for t in self.latest_twitter:
            if '[' not in t['full_text']:
                t['tag'] = TwitterAPI.twitter_classifier.classify(t['full_text'])

# %%
a = TwitterAPI(1.29464, 103.783)

# %%
a.get_latest_twitter()
# Out:
# {'tweets': {'results': [{'created_at': 'Fri Nov 17 10:21:06 +0000 2017',
#     'full_text': '[EWL]: Train svcs btwn #JooKoon &amp; #TuasLink will continue to be suspended till Sun, 19 Nov. Free regular &amp; bridging bus svcs will be avail btwn #JooKoon &amp; #TuasLink all day. Plan your journey &amp; cater for additional train travel time. Alternative transport: https://t.co/4Qu9aPQESU',
#     'tag': 'pos'},
#    {'created_at': 'Thu Nov 16 12:42:45 +0000 2017',
#     'full_text': '[EWL]: Train svcs btwn #JooKoon &amp; #TuasLink will continue to be suspended tmr. Free regular &amp; bridging bus svcs will be avail btwn #JooKoon &amp; #TuasLink all day tmr. Plan your journey early &amp; cater for additional train travel time on EWL. Other transport: https://t.co/LmN15nP6k6.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 20:44:01 +0000 2017',
#     'full_text': '[NSL]: Train service on the NSL is running normally.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 20:43:20 +0000 2017',
#     'full_text': '[EWL]:Train svc btwn #JooKoon &amp; #TuasLink is suspended. Free regular &amp; bridging bus svcs are available btwn #JooKoon &amp; #TuasLink all day.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 14:18:03 +0000 2017',
#     'full_text': '[NSL] update: Train service on North South Line has running normally now.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 12:33:26 +0000 2017',
#     'full_text': '[NSL] UPDATE: Due to fewer trains serving the NSL tmr, pls add 40mins train travel time. Free bridging bus svcs from #Yishun to #MarinaSouthPier (one way) and free regular bus svcs between #Yishun and #MarinaSouthPier (both directions) are avail from the start of train service.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 12:29:27 +0000 2017',
#     'full_text': '[EWL]UPDATE:Train svcs btwn #JooKoon &amp; #TuasLink will be suspended tmr. Free regular bus &amp; bridging bus svcs will be avail btwn #JooKoon &amp; #TuasLink all day tmr. Plan your journey early &amp; cater for additional train travel time on EWL.Alternative transport:https://t.co/LmN15nP6k6.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 12:19:43 +0000 2017',
#     'full_text': '[NSL] UPDATE: Free regular bus and bridging bus services between #Bishan and #Yishun have ended.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 10:29:29 +0000 2017',
#     'full_text': '[NSL] UPDATE: Pls add 40 mins train travel time when commuting on the NSL. Free bridging bus services from #Bishan to #Yishun (one way) and free regular bus services btwn #Bishan and #Yishun (both directions) are still avail. Commuters are advised to take alternative train lines.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 09:45:02 +0000 2017',
#     'full_text': '[NSL] UPDATE: Pls add 25 mins train travel time when commuting on the NSL. Free bridging bus services from #Bishan to #Yishun (one way) and free regular bus services btwn #Bishan and #Yishun (both directions) are available. Pls seek alternative transport: https://t.co/LmN15nP6k6.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 09:34:54 +0000 2017',
#     'full_text': '[EWL] UPDATE: Free regular bus and bridging bus services between #BoonLay and #TuasLink have ended.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 09:15:45 +0000 2017',
#     'full_text': '[EWL] UPDATE: Train services between #BoonLay and #TuasLink have resumed but are running slower. Commuters travelling between #JurongEast and #TuasLink are advised to cater additional 10 minutes travelling time.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 09:05:07 +0000 2017',
#     'full_text': '[NSL]: Due to fewer trains serving the NSL this evening, please cater additional 15 minutes train travel time. Free bridging bus services from #Bishan to #Yishun (one way) and free regular bus services between #Bishan and #Yishun (both directions) are available.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 05:58:19 +0000 2017',
#     'full_text': '[EWL] UPDATE: No train service between #BoonLay and #TuasLink. Free regular bus and bridging bus services are available between #BoonLay and #TuasLink. Please seek alternative transport: https://t.co/4Qu9aPz41m. We are sorry that your journey has been affected.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 02:31:56 +0000 2017',
#     'full_text': '[EWL] UPDATE: Please add 10 mins train travel time between #BoonLay and #TuasLink. Free regular bus services are still available between #JurongEast and #TuasLink.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 01:58:19 +0000 2017',
#     'full_text': '[EWL] UPDATE: Please add 15 mins train travel time between #JurongEast and #TuasLink. Free regular bus services are still available between #JurongEast and #TuasLink.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 01:46:28 +0000 2017',
#     'full_text': '[CCL]CLEARED: Free regular bus services have ceased.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 01:26:51 +0000 2017',
#     'full_text': '[EWL] UPDATE: Due to a train fault, please add 30mins train travel time between #Queenstown and #TuasLink. Free regular bus services are available between #JurongEast and #TuasLink.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 01:00:41 +0000 2017',
#     'full_text': '[EWL] UPDATE: Pls add 30mins train travel time btwn #JurongEast and #TuasLink. We are working to recover svc.',
#     'tag': 'pos'},
#    {'created_at': 'Wed Nov 15 00:37:47 +0000 2017',
#     'full_text': '[EWL] UPDATE: Pls add 30mins train travel time btwn #JurongEast and #TuasLink due to a train fault at #JooKoon. Train svc is available.',
#     'tag': 'pos'}],
#   'search_distance': 0.3}}
